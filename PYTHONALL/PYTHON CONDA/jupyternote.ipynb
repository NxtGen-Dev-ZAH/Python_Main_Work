# %%
print("hello")
# Out:
# hello

# %%
a_list=[1,"hello",[1,2,3],True,False,"MYNAMEISZAHEER"]
am_list=len(a_list)
am_list-1
a_list.remove("hello")
a_list.insert(3,"myname")
print(am_list)
#for x in a_list:
i=0
while i<=3:
  print(a_list[i])
  i=i+1
# Out:
# 6
# 1
# [1, 2, 3]
# True
# myname

# %%
b : str = 'string "Python"\'s with single qoute'

print(type(b))
print(b)
# Out:
# <class 'str'>
# string "Python"'s with single qoute

# %%
b :str = 'line1'\
'line3'\
'line5'
print(type(b))
print(b)
# Out:
# <class 'str'>
# line1line3line5

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2,8])
ypoints= np.array([0,230])
xdata=np.random.random(50)*100
ydata=np.random.random(50)*100

plt.plot(xpoints,ypoints)
plt.show()
plt.scatter(xdata,ydata)
plt.show()
