# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2,8])
ypoints= np.array([0,230])
xdata=np.random.random(50)*100
ydata=np.random.random(50)*100

plt.plot(xpoints,ypoints,'o')
plt.show()
plt.plot(xpoints,ypoints)
plt.show()
plt.scatter(xdata,ydata)
plt.show()

# %% [markdown]
# PLOTTING WITH X VALUES

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.xlabel("X AXIS")
plt.ylabel("Y AXIS")
plt.title("marker graph",fontdict={'fontname':'Comic Sans MS','fontsize':30},loc='left')
plt.xticks([0,2,4,6,8,10])
plt.yticks([0,3,6,8,10,12])
plt.grid(axis='x')
xdata=np.array([1,2,3,4,7,11])
ydata=np.array([3,4,1,8,10,5])
#fontdict=
#font1 = {'family':'serif','color':'blue','size':20}
#fmt is marker|line|color format string 
# MARKER MARKS THE POINT WHERE X Y MEETS
plt.plot(xdata,ydata,marker='o')
plt.show()
ypoints = np.array([3, 8, 1, 10, 5, 7])
plt.plot(ypoints,'o:r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpointss=np.array([1,2,5,6,8,9])
ypointss=np.array([2,3,4,5,6,9])
plt.plot(xpointss,ypointss,'*-.r')
plt.grid()
plt.show()

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 12,mec='r',mfc='green')
#this is the marker size as ms
#mec is the marker edge color 
#marker face color as mfc
#plt.plot(ypoints, linestyle = 'dashed') for linestyle
# =  = == = = == = ls=":" shorter syntax
# color='' ,c =''
plt.grid(color='blue',linestyle='--',linewidth=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y1=np.array([12,23,45,67,54])
y2=np.array([12,34,55,61,23])
plt.plot(y1,'o:r',ms=10)
plt.plot(y2,'*:g')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#With the subplot() function you can draw multiple plots in one figure:
#in subplot() there are three elements subplot(1,2,1) here 121 means
# there is one row two columns and last one is the index no
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2, 2, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(2, 2, 2)
plt.plot(x,y)

x = np.array([3, 5, 7, 9])
y = np.array([10, 20, 30, 40])
plt.subplot(2,2,3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(2, 2,4)
plt.plot(x,y)
plt.suptitle("SUBPLOTTING")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y,color="blue")

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y,color="red")
plt.show()

x = np.array([5,7,8,7,2,17])
y = np.array([99,86,87,88,111,86])
colorss=np.array(['red','green','orange','red','blue','black'])
plt.scatter(x,y,color=colorss)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xdata = np.random.randint(1,10,size=7)
ydata=np.random.randint(1,345,7)
m=sorted(xdata)
n=sorted(ydata)

plt.plot(m,n,'o',color='red')

plt.scatter(xdata,ydata,c='yellow')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))
plt.subplot(1,3,1)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.6, cmap='nipy_spectral')

x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))
plt.subplot(1,3,2)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='viridis')

x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))
plt.subplot(1,3,3)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='rainbow')
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.subplot(1,2,1)
plt.bar(x, y,color='red', width = 0.4)
plt.show()

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.subplot(1,2,2)
plt.barh(x, y, color = "hotpink", height =0.3)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x,bins=10,color='red',label=['data'])
plt.legend(loc='upper right' )
plt.show()


# Generate random 2D data
x = np.random.randn(1000)
y = np.random.randn(1000)

# Create a 2D histogram
plt.hist2d(x, y, bins=(50, 50), cmap='viridis')

# Customize the plot
plt.title('2D Histogram (Heatmap)')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.colorbar(label='Frequency')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
data1 = np.random.normal(150,10,500)
data2 = np.random.normal(130,5,800)

# Create a stacked histogram
plt.hist([data1, data2], bins=20, stacked=True, color=['blue', 'green'], label=['Data 1', 'Data 2'])

# Customize the plot
plt.title('Stacked Histogram of Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

# Show the plot
plt.show()
data=np.random.randn(1000)
data2=np.random.randn(1000)
plt.hist([data,data2],bins=10,color=['green','yellow'],label=['DATA1','DATA2'])
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
data1 = np.random.randn(1000)
data2 = np.random.randn(1000) + 2  # Shifted data

# Create the histogram
plt.hist([data1, data2], bins=20, alpha=0.5, color=['blue', 'green'], label=['Data 1', 'Data 2'],width=0.1)

# Customize the plot
plt.title('Histogram of Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels,startangle=90)
plt.show() 
y=np.array([35,30,10,25])
lame=('apple','mango','banana','dates')
explodee=[0.2,0,0,0]
plt.pie(y,explode=explodee,shadow=True)
plt.legend(title = "Four Fruits:",labels=lame)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('datacs.csv')
df.plot()
plt.show()
df.plot(kind='scatter',y='runs',x='balls')
dfam=df.corr()
print(dfam)
plt.show()
dataset = {'A': [120, 34, 32, 120, 45, 45,32],
           'B': [25, 6, 7, 89, 65, 6,7],
           'C': [26, 47, 89, 76, 0, 47,89]}
dfa=pd.DataFrame(dataset)
print(dfa)
DFAN=pd.read_csv('datacsv2.csv')
n=pd.DataFrame(DFAN)
n.plot(kind='scatter', x= 'Calories',y='Maxpulse')
plt.show()
print(DFAN.columns)
dfan =DFAN.drop(columns=['Date','Calories','Maxpulse'])
print(dfan.columns)
N=dfan.corr()
print(N)
dfan.plot(kind='scatter',x='Duration',y='Pulse')
plt.show()
dfan["Duration"].plot(kind='hist')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# z:\PYTHON\plot.ipynb Cell 15 line 2
#       <a href='vscode-notebook-cell:/z%3A/PYTHON/plot.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> import matplotlib.pyplot as plt
# ----> <a href='vscode-notebook-cell:/z%3A/PYTHON/plot.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> import pandas as pd
#       <a href='vscode-notebook-cell:/z%3A/PYTHON/plot.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a> df = pd.read_csv('datacs.csv')
#       <a href='vscode-notebook-cell:/z%3A/PYTHON/plot.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a> df.plot()
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot([0,1,2,3,4,5])
plt.show()
sns.displot([0, 1, 2, 3, 4, 5],kde=True,stat="density",kde_kws=dict(cut=3),alpha=.4,edgecolor=(1,1,1,.4))
#sns.kdeplot for showing only the plotted curve 
plt.show()
# Out:
# C:\Users\zahee\AppData\Local\Temp\ipykernel_5672\666388340.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0,1,2,3,4,5])
# z:\git\anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# z:\git\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %% [markdown]
# NORMAL DISTRIBUTION

# %%
import matplotlib.pyplot as plt
from numpy import random
import seaborn as sns
x = random.normal(loc=1, scale=2, size=(2, 3))
print(x)
plt.plot(x)
sns.displot(x,kde=True,stat="density",kde_kws=dict(cut=3),alpha=.4,edgecolor=(1,1,1,.4))
plt.show
# Out:
# [[-1.47611329 -1.15242873 -0.42816363]
#  [-1.91591406  1.4538887   2.20327649]]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# BINOMIAL DISTRIBUTION

# %%
import numpy as np
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

x=np.random.normal(size=100)
print(x)
p=pd.DataFrame(x)
plt.plot(p)
plt.show()
sns.distplot(x,hist=False)
plt.show()
sns.distplot(random.binomial(n=10,p=0.5,size=1000),hist=True,kde=False)
plt.show()
# Out:
# [-0.63585815  0.22186524  0.06339652  1.30443335 -0.11458643  0.42369866
#  -0.14722527  0.15157885  1.66379918  0.37155376  0.10475226 -0.24073822
#   0.78034483 -2.05645455 -0.25856466 -0.41773035 -1.80681308 -0.06091753
#   1.36315788 -1.55482418  0.13842418 -0.40958396 -0.6586266   1.66778121
#   0.5912259   0.88808856  1.46080541  0.36363897 -0.84977009 -0.43551318
#  -1.1624145   0.92177111 -0.76303359 -0.9188469   0.53558947 -0.85136442
#  -0.06327814 -0.40881705  1.82781319 -0.1226307   0.58849771  1.2498842
#  -0.50697718 -1.03039459 -0.04547268 -1.56896833  1.98307316 -0.9943595
#   0.34825005  1.35876243  0.92387955  0.57554738  0.6827039  -0.0402989
#   0.91260312  0.8434283   0.35088441  0.03717498 -1.95936127  0.56513474
#  -0.64291698  0.03452379  1.05185954 -0.51894869 -1.9599857   0.73414477
#   0.38469538 -1.4506998  -0.6715225  -0.50942829  0.48670531 -0.22332983
#   0.30835399  0.12347883  0.91659283  0.91228692  0.35544345 -0.11554736
# ...

# %% [markdown]
# # POISSION DISTRIBUTION

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

x = random.poisson(lam=2, size=(2,10))
print(x)

sns.distplot(random.poisson(lam=2, size=1000), hist=False)
plt.show()
# Out:
# [[2 3 1 4 4 2 4 2 0 2]
#  [0 2 1 0 3 1 2 3 2 0]]
# C:\Users\zahee\AppData\Local\Temp\ipykernel_5672\1067480360.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.poisson(lam=2, size=1000), hist=False)
# z:\git\anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate values
x_values = np.linspace(0, 10, 11)
y_values = x_values

# Create a figure
plt.plot(x_values, y_values, label="y = x")

# Show the figure
plt.show()

# %%
import matplotlib.pyplot as plt
class Rectangle(object):
    def __init__(self, width=2, height=3, color="r"):
        self.height = height
        self.width = width
        self.color = color

    def draw_rectangle(self):
        # Add the rectangle to the current plot
        plt.gca().add_patch(plt.Rectangle((0, 0), self.width, self.height, fc=self.color))

        # Set the axes to scale
        plt.axis("scaled")

        # Show the plot
        plt.show()

pre=Rectangle()
pre.draw_rectangle()

rectangle = Rectangle(width=5, height=10, color="blue")

# Draw the rectangle
rectangle.draw_rectangle()
